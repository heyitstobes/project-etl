# %%
import pandas as pd

# %%
codes = pd.read_csv('358_code_cdc.csv')
final2008 = pd.read_csv('final2008.csv')
final2009 = pd.read_csv('final2009.csv')
final2010 = pd.read_csv('final2010.csv')

# %%
codes = codes.rename(columns={'1':'358_cause_recode','I. Certain infectious and parasitic diseases (A00-B99)':'Cause'})
codes.head()
# Out:
#    358_cause_recode  I.  Certain infectious and parasitic diseases (A00-B99)
# 0                 2           Intestinal infectious diseases (A00-A09)
# 1                 3                                      Cholera (A00)
# 2                 4     Other intestinal infectious diseases (A01-A08)
# 3                 5                              Typhoid fever (A01.0)
# 4                 6   Paratyphoid fevers and other salmonella infec...

# %%
final2008.head()
# Out:
#    358_cause_recode  count
# 0                 5      2
# 1                 6     44
# 2                 7      3
# 3                 8      7
# 4                 9      3

# %%
final2008_merged = pd.merge(final2008,codes)

# %%
final2008_merged
# Out:
#      358_cause_recode  count  \
# 0                   5      2
# 1                   6     44
# 2                   7      3
# 3                   8      7
# 4                   9      3
# 5                  10   7747
# 6                  11    134
# 7                  13    449
# 8                  14    136
# 9                  18      3
# 10                 20     20
# 11                 21      3
# 12                 22    102
# 13                 23  35980
# 14                 24   1750
# 15                 27      1
# 16                 28     18
# 17                 29     15
# 18                 30      2
# 19                 31      3
# 20                 33     10
# 21                 35     11
# 22                 38      2
# 23                 39      2
# 24                 41     66
# 25                 42    178
# 26                 43    147
# 27                 47   7656
# 28                 49   3834
# 29                 50    848
# ..                ...    ...
# ...
